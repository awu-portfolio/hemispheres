# %% [markdown]
# # Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import datetime
from pathlib import Path

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the List of Cities

# %%
lat_lngs = []
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify the nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # Add unique cities to list
    if city not in cities:
        cities.append(city)

# City count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 605

# %%
# Print JSON

city_url_json = "http://api.openweathermap.org/data/2.5/weather?q="+"port-aux-francais"+"&units=metric&appid="+weather_api_key
response = requests.get(city_url_json).json()
print(response)
# Out:
# {'coord': {'lon': 70.2167, 'lat': -49.35}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 5.62, 'feels_like': -0.2, 'temp_min': 5.62, 'temp_max': 5.62, 'pressure': 1001, 'humidity': 83, 'sea_level': 1001, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 12.58, 'deg': 309, 'gust': 16.4}, 'clouds': {'all': 100}, 'dt': 1735151419, 'sys': {'country': 'TF', 'sunrise': 1735081902, 'sunset': 1735140400}, 'timezone': 18000, 'id': 1546102, 'name': 'Port-aux-Français', 'cod': 200}

# %% [markdown]
# ---

# %% [markdown]
# ## Plots Showcasing the Relationship Between Weather Variables and Latitude
#
# ### Retrieving weather data from the cities using the OpenWeatherMap API

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url+"q="+city+"&units=metric&appid="+weather_api_key

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print(f"City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grytviken
# Processing Record 2 of Set 1 | port-aux-francais
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | joshimath
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | arkhangel'sk
# Processing Record 7 of Set 1 | edinburgh of the seven seas
# Processing Record 8 of Set 1 | harper
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | st. john's
# Processing Record 11 of Set 1 | uturoa
# Processing Record 12 of Set 1 | ponta delgada
# Processing Record 13 of Set 1 | invercargill
# Processing Record 14 of Set 1 | tiksi
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | udachny
# Processing Record 17 of Set 1 | iqaluit
# Processing Record 18 of Set 1 | salinopolis
# Processing Record 19 of Set 1 | puerto ayora
# Processing Record 20 of Set 1 | margate
# Processing Record 21 of Set 1 | am djarass
# City not found. Skipping...
# Processing Record 22 of Set 1 | puerto natales
# Processing Record 23 of Set 1 | madara
# Processing Record 24 of Set 1 | san patricio
# Processing Record 25 of Set 1 | saudarkrokur
# Processing Record 26 of Set 1 | vilyuchinsk
# Processing Record 27 of Set 1 | gornopravdinsk
# Processing Record 28 of Set 1 | rovnoye
# Processing Record 29 of Set 1 | menongue
# Processing Record 30 of Set 1 | hawaiian paradise park
# Processing Record 31 of Set 1 | port lincoln
# Processing Record 32 of Set 1 | soroti
# Processing Record 33 of Set 1 | college
# Processing Record 34 of Set 1 | junnar
# Processing Record 35 of Set 1 | bako
# Processing Record 36 of Set 1 | namibe
# Processing Record 37 of Set 1 | hongwon
# Processing Record 38 of Set 1 | isafjordur
# Processing Record 39 of Set 1 | cidreira
# Processing Record 40 of Set 1 | remire-montjoly
# Processing Record 41 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 42 of Set 1 | gadzhiyevo
# Processing Record 43 of Set 1 | valenca do piaui
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | georgetown
# Processing Record 47 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 48 of Set 1 | daru
# Processing Record 49 of Set 1 | adamstown
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 0 of Set 2 | beberibe
# Processing Record 1 of Set 2 | saipan
# Processing Record 2 of Set 2 | andergrove
# Processing Record 3 of Set 2 | bay roberts
# Processing Record 4 of Set 2 | krasnoshchekovo
# Processing Record 5 of Set 2 | tekeli
# Processing Record 6 of Set 2 | tura
# Processing Record 7 of Set 2 | puerto san carlos
# City not found. Skipping...
# Processing Record 8 of Set 2 | rock springs
# Processing Record 9 of Set 2 | soio
# Processing Record 10 of Set 2 | palikir - national government center
# Processing Record 11 of Set 2 | klyuchi
# Processing Record 12 of Set 2 | monrovia
# Processing Record 13 of Set 2 | benguela
# Processing Record 14 of Set 2 | happy valley-goose bay
# Processing Record 15 of Set 2 | vorgashor
# Processing Record 16 of Set 2 | haiku-pauwela
# Processing Record 17 of Set 2 | olonkinbyen
# Processing Record 18 of Set 2 | shache
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | governor's harbour
# City not found. Skipping...
# Processing Record 21 of Set 2 | aasiaat
# Processing Record 22 of Set 2 | mancio lima
# Processing Record 23 of Set 2 | djougou
# Processing Record 24 of Set 2 | mount isa
# Processing Record 25 of Set 2 | san juan de miraflores
# Processing Record 26 of Set 2 | lido di jesolo
# Processing Record 27 of Set 2 | hadibu
# Processing Record 28 of Set 2 | pasni
# Processing Record 29 of Set 2 | belmonte
# Processing Record 30 of Set 2 | gorontalo
# Processing Record 31 of Set 2 | saint-pierre
# Processing Record 32 of Set 2 | celestun
# Processing Record 33 of Set 2 | colonia
# Processing Record 34 of Set 2 | arraial do cabo
# Processing Record 35 of Set 2 | bethel
# Processing Record 36 of Set 2 | papatowai
# Processing Record 37 of Set 2 | wailua homesteads
# Processing Record 38 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 2 | puerto aysen
# Processing Record 40 of Set 2 | ancud
# Processing Record 41 of Set 2 | north bay
# Processing Record 42 of Set 2 | manadhoo
# Processing Record 43 of Set 2 | itoman
# Processing Record 44 of Set 2 | sitka
# Processing Record 45 of Set 2 | san juan bautista
# Processing Record 46 of Set 2 | hayma'
# City not found. Skipping...
# Processing Record 47 of Set 2 | selfoss
# Processing Record 48 of Set 2 | whitehorse
# Processing Record 49 of Set 2 | yerofey pavlovich
# Processing Record 0 of Set 3 | howrah
# Processing Record 1 of Set 3 | susuman
# Processing Record 2 of Set 3 | ushuaia
# Processing Record 3 of Set 3 | roma
# Processing Record 4 of Set 3 | dong ha
# Processing Record 5 of Set 3 | rio gallegos
# Processing Record 6 of Set 3 | hamilton
# Processing Record 7 of Set 3 | bandarbeyla
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | novyy urgal
# Processing Record 10 of Set 3 | malangali
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | nkurenkuru
# City not found. Skipping...
# Processing Record 13 of Set 3 | brookings
# Processing Record 14 of Set 3 | ungsang
# Processing Record 15 of Set 3 | albany
# Processing Record 16 of Set 3 | tolanaro
# Processing Record 17 of Set 3 | zag
# Processing Record 18 of Set 3 | hermantown
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | shadipur julana
# Processing Record 21 of Set 3 | blackwater
# Processing Record 22 of Set 3 | ciudad acuna
# Processing Record 23 of Set 3 | taltal
# Processing Record 24 of Set 3 | zeya
# Processing Record 25 of Set 3 | geraldton
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | la ronge
# Processing Record 28 of Set 3 | hami
# Processing Record 29 of Set 3 | homer
# Processing Record 30 of Set 3 | bilibino
# Processing Record 31 of Set 3 | tralee
# Processing Record 32 of Set 3 | howard springs
# Processing Record 33 of Set 3 | hobyo
# Processing Record 34 of Set 3 | san jose village
# City not found. Skipping...
# Processing Record 35 of Set 3 | blackmans bay
# Processing Record 36 of Set 3 | crane
# Processing Record 37 of Set 3 | mula
# Processing Record 38 of Set 3 | asadabad
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | lihue
# Processing Record 41 of Set 3 | port hueneme
# Processing Record 42 of Set 3 | villa angela
# Processing Record 43 of Set 3 | jayapura
# Processing Record 44 of Set 3 | tazovsky
# Processing Record 45 of Set 3 | vingt cinq
# City not found. Skipping...
# Processing Record 46 of Set 3 | stanley
# Processing Record 47 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 3 | coquimbo
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 0 of Set 4 | port mathurin
# Processing Record 1 of Set 4 | severo-yeniseyskiy
# Processing Record 2 of Set 4 | lagoa
# Processing Record 3 of Set 4 | margaret river
# Processing Record 4 of Set 4 | al matlin
# Processing Record 5 of Set 4 | atafu village
# Processing Record 6 of Set 4 | valley city
# Processing Record 7 of Set 4 | zhelezinka
# Processing Record 8 of Set 4 | mahibadhoo
# Processing Record 9 of Set 4 | talnakh
# Processing Record 10 of Set 4 | kodiak
# Processing Record 11 of Set 4 | ormara
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | arkadak
# Processing Record 14 of Set 4 | i-n-salah
# Processing Record 15 of Set 4 | baiti
# Processing Record 16 of Set 4 | kendal
# Processing Record 17 of Set 4 | kapa'a
# Processing Record 18 of Set 4 | anadyr
# Processing Record 19 of Set 4 | ust-nera
# Processing Record 20 of Set 4 | petropavlovsk-kamchatsky
# Processing Record 21 of Set 4 | keflavik
# Processing Record 22 of Set 4 | ndioum
# Processing Record 23 of Set 4 | vernon
# Processing Record 24 of Set 4 | bemetara
# Processing Record 25 of Set 4 | carutapera
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | utrik
# Processing Record 28 of Set 4 | east london
# Processing Record 29 of Set 4 | queenstown
# Processing Record 30 of Set 4 | enewetak
# Processing Record 31 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 32 of Set 4 | tanjung selor
# Processing Record 33 of Set 4 | bargara
# City not found. Skipping...
# Processing Record 34 of Set 4 | gaillimh
# Processing Record 35 of Set 4 | an nuhud
# Processing Record 36 of Set 4 | saint john
# Processing Record 37 of Set 4 | antalaha
# Processing Record 38 of Set 4 | tevragh zeina
# City not found. Skipping...
# Processing Record 39 of Set 4 | fale old settlement
# Processing Record 40 of Set 4 | nelson bay
# Processing Record 41 of Set 4 | kilindoni
# Processing Record 42 of Set 4 | kidal
# Processing Record 43 of Set 4 | constantia
# Processing Record 44 of Set 4 | harrison
# Processing Record 45 of Set 4 | faya-largeau
# Processing Record 46 of Set 4 | chonchi
# Processing Record 47 of Set 4 | nova sintra
# Processing Record 48 of Set 4 | bikenibeu village
# Processing Record 49 of Set 4 | saint-gilles
# Processing Record 0 of Set 5 | flying fish cove
# Processing Record 1 of Set 5 | miranda
# Processing Record 2 of Set 5 | mount gambier
# Processing Record 3 of Set 5 | launceston
# Processing Record 4 of Set 5 | qaqortoq
# Processing Record 5 of Set 5 | ourem
# Processing Record 6 of Set 5 | sao miguel do araguaia
# Processing Record 7 of Set 5 | karukh
# Processing Record 8 of Set 5 | rongelap
# Processing Record 9 of Set 5 | dudinka
# Processing Record 10 of Set 5 | chirchiq
# Processing Record 11 of Set 5 | kamina
# Processing Record 12 of Set 5 | atherton
# Processing Record 13 of Set 5 | paranhos
# Processing Record 14 of Set 5 | kingston
# Processing Record 15 of Set 5 | safford
# Processing Record 16 of Set 5 | egilsstadir
# Processing Record 17 of Set 5 | jumla
# Processing Record 18 of Set 5 | abeche
# Processing Record 19 of Set 5 | grande prairie
# Processing Record 20 of Set 5 | cargados carajos
# City not found. Skipping...
# Processing Record 21 of Set 5 | portland
# Processing Record 22 of Set 5 | mount pearl
# Processing Record 23 of Set 5 | port elizabeth
# Processing Record 24 of Set 5 | bontang
# Processing Record 25 of Set 5 | lazaro cardenas
# Processing Record 26 of Set 5 | leava
# Processing Record 27 of Set 5 | nishinoomote
# Processing Record 28 of Set 5 | dire dawa
# Processing Record 29 of Set 5 | merritt
# Processing Record 30 of Set 5 | la passe
# Processing Record 31 of Set 5 | primorsko-akhtarsk
# Processing Record 32 of Set 5 | wad medani
# Processing Record 33 of Set 5 | kaluga
# Processing Record 34 of Set 5 | igarka
# Processing Record 35 of Set 5 | ringkobing
# Processing Record 36 of Set 5 | newman
# Processing Record 37 of Set 5 | marshfield
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | port glaud
# City not found. Skipping...
# Processing Record 40 of Set 5 | stolac
# Processing Record 41 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 42 of Set 5 | axim
# Processing Record 43 of Set 5 | arta
# Processing Record 44 of Set 5 | vadso
# Processing Record 45 of Set 5 | progreso
# Processing Record 46 of Set 5 | island harbour
# Processing Record 47 of Set 5 | gizo
# Processing Record 48 of Set 5 | avarua
# Processing Record 49 of Set 5 | kaa-khem
# Processing Record 0 of Set 6 | lompoc
# Processing Record 1 of Set 6 | cockburn town
# Processing Record 2 of Set 6 | fuyu
# Processing Record 3 of Set 6 | kalymnos
# Processing Record 4 of Set 6 | sinabang
# Processing Record 5 of Set 6 | sanghar
# Processing Record 6 of Set 6 | port alfred
# Processing Record 7 of Set 6 | noyabrsk
# Processing Record 8 of Set 6 | le port
# Processing Record 9 of Set 6 | ta`u
# Processing Record 10 of Set 6 | urangan
# Processing Record 11 of Set 6 | arys
# Processing Record 12 of Set 6 | nevel'
# Processing Record 13 of Set 6 | abadeh
# Processing Record 14 of Set 6 | gisborne
# Processing Record 15 of Set 6 | plouzane
# Processing Record 16 of Set 6 | ninghai
# Processing Record 17 of Set 6 | almeirim
# Processing Record 18 of Set 6 | ilulissat
# Processing Record 19 of Set 6 | shimoda
# Processing Record 20 of Set 6 | mamuju
# Processing Record 21 of Set 6 | as suwayq
# Processing Record 22 of Set 6 | trincomalee
# Processing Record 23 of Set 6 | rabo de peixe
# Processing Record 24 of Set 6 | rio grande
# Processing Record 25 of Set 6 | sungai penuh
# Processing Record 26 of Set 6 | puerto leguizamo
# Processing Record 27 of Set 6 | tarakan
# Processing Record 28 of Set 6 | kanggye
# Processing Record 29 of Set 6 | pristen'
# Processing Record 30 of Set 6 | harlan
# Processing Record 31 of Set 6 | villa gesell
# Processing Record 32 of Set 6 | port saint john's
# Processing Record 33 of Set 6 | prince rupert
# Processing Record 34 of Set 6 | nahiyat ash shinafiyah
# Processing Record 35 of Set 6 | gladstone
# Processing Record 36 of Set 6 | verkhnevilyuysk
# Processing Record 37 of Set 6 | caleta de carquin
# Processing Record 38 of Set 6 | sisimiut
# Processing Record 39 of Set 6 | grand-lahou
# Processing Record 40 of Set 6 | concepcion
# Processing Record 41 of Set 6 | taitung city
# Processing Record 42 of Set 6 | lospalos
# Processing Record 43 of Set 6 | machico
# Processing Record 44 of Set 6 | paka
# Processing Record 45 of Set 6 | hotan
# Processing Record 46 of Set 6 | ebaye
# Processing Record 47 of Set 6 | nova vicosa
# Processing Record 48 of Set 6 | camana
# Processing Record 49 of Set 6 | saksaul'skiy
# City not found. Skipping...
# Processing Record 0 of Set 7 | dunedin
# Processing Record 1 of Set 7 | las tablas
# Processing Record 2 of Set 7 | nalhati
# Processing Record 3 of Set 7 | afaahiti
# Processing Record 4 of Set 7 | hammerfest
# Processing Record 5 of Set 7 | watertown
# Processing Record 6 of Set 7 | polyarnyy
# Processing Record 7 of Set 7 | iskateley
# Processing Record 8 of Set 7 | las terrenas
# Processing Record 9 of Set 7 | wanning
# Processing Record 10 of Set 7 | eirunepe
# Processing Record 11 of Set 7 | vilyuysk
# Processing Record 12 of Set 7 | hauterive
# Processing Record 13 of Set 7 | morant bay
# Processing Record 14 of Set 7 | cortina d'ampezzo
# Processing Record 15 of Set 7 | ketchikan
# Processing Record 16 of Set 7 | sola
# Processing Record 17 of Set 7 | suva
# Processing Record 18 of Set 7 | brooks
# Processing Record 19 of Set 7 | acapulco de juarez
# Processing Record 20 of Set 7 | conde
# Processing Record 21 of Set 7 | luena
# Processing Record 22 of Set 7 | mwene-ditu
# Processing Record 23 of Set 7 | tebessa
# Processing Record 24 of Set 7 | labuan
# Processing Record 25 of Set 7 | chany
# Processing Record 26 of Set 7 | totoras
# Processing Record 27 of Set 7 | porto novo
# Processing Record 28 of Set 7 | waingapu
# Processing Record 29 of Set 7 | timimoun
# Processing Record 30 of Set 7 | antonio enes
# Processing Record 31 of Set 7 | saldanha
# Processing Record 32 of Set 7 | semirom
# Processing Record 33 of Set 7 | castillos
# Processing Record 34 of Set 7 | chernyshevskiy
# Processing Record 35 of Set 7 | fannuj
# City not found. Skipping...
# Processing Record 36 of Set 7 | nizhneudinsk
# Processing Record 37 of Set 7 | polovinnoye
# Processing Record 38 of Set 7 | miracema do tocantins
# Processing Record 39 of Set 7 | touros
# Processing Record 40 of Set 7 | barcelona
# Processing Record 41 of Set 7 | west island
# Processing Record 42 of Set 7 | zakynthos
# Processing Record 43 of Set 7 | vorkuta
# Processing Record 44 of Set 7 | petrovsk
# Processing Record 45 of Set 7 | sandnessjoen
# Processing Record 46 of Set 7 | hanceville
# Processing Record 47 of Set 7 | znamenskoye
# Processing Record 48 of Set 7 | carnarvon
# Processing Record 49 of Set 7 | clarkston heights-vineland
# Processing Record 0 of Set 8 | zhanaozen
# Processing Record 1 of Set 8 | masuda
# Processing Record 2 of Set 8 | kolonia town
# Processing Record 3 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 4 of Set 8 | dzilam gonzalez
# Processing Record 5 of Set 8 | fort bragg
# Processing Record 6 of Set 8 | gembu
# Processing Record 7 of Set 8 | al bawiti
# Processing Record 8 of Set 8 | sumenep
# Processing Record 9 of Set 8 | nalut
# Processing Record 10 of Set 8 | horta
# Processing Record 11 of Set 8 | sant antoni de portmany
# Processing Record 12 of Set 8 | darwin
# Processing Record 13 of Set 8 | manokwari
# Processing Record 14 of Set 8 | weno
# Processing Record 15 of Set 8 | griffith
# Processing Record 16 of Set 8 | beihai
# Processing Record 17 of Set 8 | hemsby
# Processing Record 18 of Set 8 | kerikeri
# Processing Record 19 of Set 8 | kapuskasing
# Processing Record 20 of Set 8 | sayan
# Processing Record 21 of Set 8 | richards bay
# Processing Record 22 of Set 8 | krolevets'
# City not found. Skipping...
# Processing Record 23 of Set 8 | vetralla
# Processing Record 24 of Set 8 | tubarao
# Processing Record 25 of Set 8 | taksimo
# Processing Record 26 of Set 8 | lebyazh'ye
# Processing Record 27 of Set 8 | shimokizukuri
# Processing Record 28 of Set 8 | pangody
# Processing Record 29 of Set 8 | ishigaki
# Processing Record 30 of Set 8 | cable beach
# City not found. Skipping...
# Processing Record 31 of Set 8 | puerto baquerizo moreno
# Processing Record 32 of Set 8 | mogocha
# Processing Record 33 of Set 8 | kaohsiung
# Processing Record 34 of Set 8 | skikda
# Processing Record 35 of Set 8 | nar'yan-mar
# Processing Record 36 of Set 8 | cova figueira
# Processing Record 37 of Set 8 | tamanrasset
# Processing Record 38 of Set 8 | cumaribo
# City not found. Skipping...
# Processing Record 39 of Set 8 | salekhard
# Processing Record 40 of Set 8 | katsuura
# Processing Record 41 of Set 8 | zima
# Processing Record 42 of Set 8 | tekirova
# Processing Record 43 of Set 8 | essaouira
# Processing Record 44 of Set 8 | kenai
# Processing Record 45 of Set 8 | wynyard
# Processing Record 46 of Set 8 | pangai
# Processing Record 47 of Set 8 | smithers
# Processing Record 48 of Set 8 | nizhnevartovsk
# Processing Record 49 of Set 8 | tosontsengel
# Processing Record 0 of Set 9 | kawambwa
# Processing Record 1 of Set 9 | funafuti
# Processing Record 2 of Set 9 | nacala
# Processing Record 3 of Set 9 | mezhdurechensk
# Processing Record 4 of Set 9 | bardai
# Processing Record 5 of Set 9 | gambela
# Processing Record 6 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 7 of Set 9 | poteau
# Processing Record 8 of Set 9 | mili
# Processing Record 9 of Set 9 | rio san juan
# Processing Record 10 of Set 9 | antofagasta
# Processing Record 11 of Set 9 | dul'durga
# Processing Record 12 of Set 9 | puerto madryn
# Processing Record 13 of Set 9 | cascais
# Processing Record 14 of Set 9 | arroyo
# Processing Record 15 of Set 9 | arauca
# Processing Record 16 of Set 9 | akcakale
# Processing Record 17 of Set 9 | vryburg
# Processing Record 18 of Set 9 | ilhabela
# Processing Record 19 of Set 9 | slave lake
# Processing Record 20 of Set 9 | olavarria
# Processing Record 21 of Set 9 | morehead city
# Processing Record 22 of Set 9 | mata-utu
# Processing Record 23 of Set 9 | quepos
# Processing Record 24 of Set 9 | babayevo
# Processing Record 25 of Set 9 | saint-francois
# Processing Record 26 of Set 9 | fukagawa
# Processing Record 27 of Set 9 | tromso
# Processing Record 28 of Set 9 | indramayu
# Processing Record 29 of Set 9 | altpinar
# Processing Record 30 of Set 9 | olonets
# Processing Record 31 of Set 9 | fengkou
# Processing Record 32 of Set 9 | ocampo
# Processing Record 33 of Set 9 | kirgiz-miyaki
# Processing Record 34 of Set 9 | altai
# Processing Record 35 of Set 9 | kampong cham
# Processing Record 36 of Set 9 | baie-comeau
# Processing Record 37 of Set 9 | vila franca do campo
# Processing Record 38 of Set 9 | umm kaddadah
# Processing Record 39 of Set 9 | xilin hot
# Processing Record 40 of Set 9 | makushino
# Processing Record 41 of Set 9 | pemba
# Processing Record 42 of Set 9 | tortoli
# Processing Record 43 of Set 9 | acajutla
# Processing Record 44 of Set 9 | sampit
# Processing Record 45 of Set 9 | marrakesh
# Processing Record 46 of Set 9 | paris
# Processing Record 47 of Set 9 | al mindak
# Processing Record 48 of Set 9 | partizanske
# Processing Record 49 of Set 9 | souran
# Processing Record 0 of Set 10 | olgii
# City not found. Skipping...
# Processing Record 1 of Set 10 | tanrake village
# City not found. Skipping...
# Processing Record 2 of Set 10 | la'ie
# Processing Record 3 of Set 10 | labytnangi
# Processing Record 4 of Set 10 | chifeng
# Processing Record 5 of Set 10 | owando
# Processing Record 6 of Set 10 | mil'kovo
# Processing Record 7 of Set 10 | estelle
# Processing Record 8 of Set 10 | isparta
# Processing Record 9 of Set 10 | cherepanovo
# Processing Record 10 of Set 10 | coos bay
# Processing Record 11 of Set 10 | kalpi
# Processing Record 12 of Set 10 | afif
# Processing Record 13 of Set 10 | ndele
# Processing Record 14 of Set 10 | huocheng
# City not found. Skipping...
# Processing Record 15 of Set 10 | bubaque
# Processing Record 16 of Set 10 | puerto armuelles
# Processing Record 17 of Set 10 | leer
# Processing Record 18 of Set 10 | kalawit
# Processing Record 19 of Set 10 | tobi village
# City not found. Skipping...
# Processing Record 20 of Set 10 | bhamo
# Processing Record 21 of Set 10 | mahina
# Processing Record 22 of Set 10 | ierapetra
# Processing Record 23 of Set 10 | tut
# Processing Record 24 of Set 10 | paita
# Processing Record 25 of Set 10 | luderitz
# Processing Record 26 of Set 10 | inhambane
# Processing Record 27 of Set 10 | sengkang
# Processing Record 28 of Set 10 | fort mcmurray
# Processing Record 29 of Set 10 | namtsy
# Processing Record 30 of Set 10 | san pedro
# Processing Record 31 of Set 10 | palmer
# Processing Record 32 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 10 | san-pedro
# Processing Record 34 of Set 10 | shunyi
# Processing Record 35 of Set 10 | akrehamn
# Processing Record 36 of Set 10 | quelimane
# Processing Record 37 of Set 10 | semey
# Processing Record 38 of Set 10 | huanren
# Processing Record 39 of Set 10 | vigan
# Processing Record 40 of Set 10 | barbacoas
# Processing Record 41 of Set 10 | turpan
# Processing Record 42 of Set 10 | okha
# Processing Record 43 of Set 10 | guaruja
# Processing Record 44 of Set 10 | zouerate
# Processing Record 45 of Set 10 | bel ombre
# Processing Record 46 of Set 10 | beyneu
# Processing Record 47 of Set 10 | santiago de cuba
# Processing Record 48 of Set 10 | sydney mines
# Processing Record 49 of Set 10 | kolonia
# Processing Record 0 of Set 11 | bengkulu
# Processing Record 1 of Set 11 | anaime
# Processing Record 2 of Set 11 | labrador city
# Processing Record 3 of Set 11 | tranovaho
# City not found. Skipping...
# Processing Record 4 of Set 11 | mossel bay
# Processing Record 5 of Set 11 | qamdo
# Processing Record 6 of Set 11 | khandyga
# Processing Record 7 of Set 11 | valledupar
# Processing Record 8 of Set 11 | mequon
# Processing Record 9 of Set 11 | barma
# Processing Record 10 of Set 11 | maiwut
# City not found. Skipping...
# Processing Record 11 of Set 11 | yulinshi
# Processing Record 12 of Set 11 | luis correia
# Processing Record 13 of Set 11 | ziguinchor
# Processing Record 14 of Set 11 | pathein
# Processing Record 15 of Set 11 | impfondo
# Processing Record 16 of Set 11 | pandan
# Processing Record 17 of Set 11 | lee acres
# Processing Record 18 of Set 11 | sirre
# Processing Record 19 of Set 11 | north battleford
# Processing Record 20 of Set 11 | muisne
# Processing Record 21 of Set 11 | chamical
# Processing Record 22 of Set 11 | luwuk
# Processing Record 23 of Set 11 | talcahuano
# Processing Record 24 of Set 11 | ressano garcia
# Processing Record 25 of Set 11 | antsiranana
# Processing Record 26 of Set 11 | white river
# Processing Record 27 of Set 11 | khovd
# Processing Record 28 of Set 11 | stornoway
# Processing Record 29 of Set 11 | tofol
# Processing Record 30 of Set 11 | palamos
# Processing Record 31 of Set 11 | kolwezi
# Processing Record 32 of Set 11 | yorkton
# Processing Record 33 of Set 11 | kambove
# Processing Record 34 of Set 11 | san luis de la loma
# Processing Record 35 of Set 11 | nadym
# Processing Record 36 of Set 11 | we
# City not found. Skipping...
# Processing Record 37 of Set 11 | broken hill
# Processing Record 38 of Set 11 | playa del ingles
# Processing Record 39 of Set 11 | scarborough
# Processing Record 40 of Set 11 | taoudenni
# Processing Record 41 of Set 11 | mokhotlong
# Processing Record 42 of Set 11 | san antonio de pale
# Processing Record 43 of Set 11 | sydney
# Processing Record 44 of Set 11 | kourou
# Processing Record 45 of Set 11 | cabedelo
# Processing Record 46 of Set 11 | utete
# Processing Record 47 of Set 11 | taro
# Processing Record 48 of Set 11 | yaren
# Processing Record 49 of Set 11 | barcelos
# Processing Record 0 of Set 12 | abalak
# Processing Record 1 of Set 12 | valparaiso
# Processing Record 2 of Set 12 | bati
# Processing Record 3 of Set 12 | nizhniy kuranakh
# Processing Record 4 of Set 12 | tashtyp
# Processing Record 5 of Set 12 | aykhal
# Processing Record 6 of Set 12 | nantucket
# Processing Record 7 of Set 12 | la cruz
# Processing Record 8 of Set 12 | aver-o-mar
# Processing Record 9 of Set 12 | yantzaza
# Processing Record 10 of Set 12 | chicxulub puerto
# City not found. Skipping...
# Processing Record 11 of Set 12 | san vicente de canete
# Processing Record 12 of Set 12 | yuzhno-kurilsk
# Processing Record 13 of Set 12 | sinjai
# Processing Record 14 of Set 12 | torghay
# Processing Record 15 of Set 12 | takab
# Processing Record 16 of Set 12 | nemuro
# Processing Record 17 of Set 12 | hailey
# Processing Record 18 of Set 12 | shendi
# Processing Record 19 of Set 12 | diguvametta
# City not found. Skipping...
# Processing Record 20 of Set 12 | aranda de duero
# Processing Record 21 of Set 12 | hoxtolgay
# City not found. Skipping...
# Processing Record 22 of Set 12 | laguna
# Processing Record 23 of Set 12 | kamaishi
# Processing Record 24 of Set 12 | tadine
# Processing Record 25 of Set 12 | guerrero negro
# Processing Record 26 of Set 12 | alupka
# Processing Record 27 of Set 12 | khuzdar
# Processing Record 28 of Set 12 | barra de santo antonio
# Processing Record 29 of Set 12 | xining
# Processing Record 30 of Set 12 | qusmuryn
# Processing Record 31 of Set 12 | gadani
# Processing Record 32 of Set 12 | saint-zotique
# Processing Record 33 of Set 12 | krasnogorskiy
# Processing Record 34 of Set 12 | ilanskiy
# Processing Record 35 of Set 12 | novyy urengoy
# Processing Record 36 of Set 12 | berezovyy
# Processing Record 37 of Set 12 | maintirano
# Processing Record 38 of Set 12 | khanty-mansiysk
# Processing Record 39 of Set 12 | isangel
# Processing Record 40 of Set 12 | jau
# Processing Record 41 of Set 12 | dakhla
# Processing Record 42 of Set 12 | harstad
# Processing Record 43 of Set 12 | villagarzon
# Processing Record 44 of Set 12 | mar del plata
# Processing Record 45 of Set 12 | kinablangan
# Processing Record 46 of Set 12 | jijiga
# Processing Record 47 of Set 12 | nainpur
# Processing Record 48 of Set 12 | quellon
# Processing Record 49 of Set 12 | zhongshu
# Processing Record 0 of Set 13 | burang
# Processing Record 1 of Set 13 | al kharj
# Processing Record 2 of Set 13 | banda aceh
# Processing Record 3 of Set 13 | glace bay
# Processing Record 4 of Set 13 | kamloops
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
    
# Show Record Count
city_data_df.count()
# Out:
# City        570
# Lat         570
# Lng         570
# Max Temp    570
# Country     570
# Date        570
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp Country        Date
# 0          grytviken -54.2811  -36.5092      1.12      GS  1735151422
# 1  port-aux-francais -49.3500   70.2167      5.62      TF  1735151419
# 2           waitangi -43.9535 -176.5597     16.57      NZ  1735151424
# 3          joshimath  30.5667   79.5667     -0.81      IN  1735151425
# 4     ribeira grande  38.5167  -28.7000     16.22      PT  1735151426

# %%
# Read saved data
city_data_df = pd.read_csv("data/city_data.csv", index_col="City")
city_data_df = city_data_df.drop("Unnamed: 0", axis=1)

city_data_df.to_csv("data/city_data.csv", header=True)

# Display sample data
city_data_df.head()
# Out:
#                        Lat       Lng  Max Temp Country        Date
# City
# ust-nera           64.5667  143.2000    -25.18      RU  1734587315
# berriane           32.8265    3.7669      9.53      DZ  1734587316
# qaqortoq           60.7167  -46.0333     -1.55      GL  1734587317
# port saint john's -31.6229   29.5448     21.00      ZA  1734587318
# martaban           16.5314   97.6111     31.13      MM  1734587319

# %% [markdown]
# ### Scatter Plots
#
# #### Latitude Vs. Temperature

# %%
file = Path("data/city_data.csv")
city_data = pd.read_csv(file, encoding="utf-8")

# Build scatter plot for latitude vs. temperature
lat = city_data["Lat"]
temp = city_data["Max Temp"]

plt.scatter(lat, temp, c=temp, cmap='coolwarm', edgecolor="black", marker="o", linewidths=0.3)

# Extract date
timestamp = city_data.iloc[0, 5]
date = datetime.datetime.utcfromtimestamp(timestamp)
formatted_date = date.strftime("%Y-%m-%d")

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title(f"City Latitude vs. Max Temperature ({formatted_date})")

# Save the figure
plt.savefig("visuals/scatter.png", transparent=True)

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Linear Regression

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data[city_data["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#        City      Lat       Lng  Max Temp Country        Date
# 0  ust-nera  64.5667  143.2000    -25.18      RU  1734587315
# 1  berriane  32.8265    3.7669      9.53      DZ  1734587316
# 2  qaqortoq  60.7167  -46.0333     -1.55      GL  1734587317
# 4  martaban  16.5314   97.6111     31.13      MM  1734587319
# 5  timimoun  29.2639    0.2310      3.21      DZ  1734587320

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data[city_data["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                            City      Lat       Lng  Max Temp Country  \
# 3             port saint john's -31.6229   29.5448     21.00      ZA
# 7                  invercargill -46.4000  168.3500     18.90      NZ
# 9   edinburgh of the seven seas -37.0676  -12.3116     14.07      SH
# 12                    grytviken -54.2811  -36.5092      2.29      GS
# 15                     mata-utu -13.2816 -176.1745     28.87      WF
#
#           Date
# 3   1734587318
# 7   1734587322
# 9   1734587325
# 12  1734587328
# 15  1734587331

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
n_lat = northern_hemi_df["Lat"]
n_temp = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(n_lat, n_temp)
regress_values = n_lat * slope + intercept
r_squared = np.power(rvalue, 2)

# Linear regression plot
plt.plot(n_lat, regress_values, label=f"y={slope:.2f}x + {intercept:.2f}", color="black")

# Scatterplot
plt.scatter(n_lat, n_temp, c=n_temp, cmap='coolwarm', edgecolor="black", marker="o", linewidths=0.3)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.title("Latitude vs. Max Temp (Northern Hemisphere)")
plt.legend()

# Save the figure
plt.savefig("visuals/north_regress.png", transparent=True)

# Show plot
print(f"The r^2 value is {r_squared}.")
plt.show()
# Out:
# The r^2 value is 0.7871253240751528.

# %%
# Linear regression on Southern Hemisphere
s_lat = southern_hemi_df["Lat"]
s_temp = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(s_lat, s_temp)
regress_values = s_lat * slope + intercept
r_squared = np.power(rvalue, 2)

# Linear regression plot
plt.plot(s_lat, regress_values, label=f"y={slope:2f}x + {intercept:2f}", color="black")

# Scatterplot
plt.scatter(s_lat, s_temp, c=s_temp, cmap='coolwarm', edgecolor="black", marker="o", linewidths=0.3)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temp (C)")
plt.title("Latitude vs. Max Temp (Southern Hemisphere)")
plt.legend()

# Save the figure
plt.savefig("visuals/south_regress.png", transparent=True)

# Show plot
print(f"The r^2 value is {r_squared}.")
plt.show()
# Out:
# The r^2 value is 0.31275888121363205.
