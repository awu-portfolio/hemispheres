# %% [markdown]
# # Hotel Finder

# %%
# Dependencies and Setup
import hvplot.pandas
import holoviews as hv
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the city data
city_data_df = pd.read_csv("data/city_data.csv")

city_data_df = city_data_df.drop("Unnamed: 0", axis=1)

# Display sample data
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp Country        Date
# 0           ust-nera  64.5667  143.2000    -25.18      RU  1734587315
# 1           berriane  32.8265    3.7669      9.53      DZ  1734587316
# 2           qaqortoq  60.7167  -46.0333     -1.55      GL  1734587317
# 3  port saint john's -31.6229   29.5448     21.00      ZA  1734587318
# 4           martaban  16.5314   97.6111     31.13      MM  1734587319

# %% [markdown]
# ---
#
# ### Map of Cities

# %%
# Configure the map plot
map_plot = city_data_df.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", size=10, color="City", 
                                      frame_width=700, frame_height=500, scale=1, alpha=0.5)

# Display the map
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City)

# %% [markdown]
# ### Step 2: Narrow down the list of cities to fit your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values

# Example Criteria: between 18 and 26 degrees Celsius, less than 60% humidity
city_data_df = city_data_df[(city_data_df["Max Temp"] <=26) & (city_data_df["Max Temp"] >=18)]

# Drop any rows with null values
city_data_df.dropna(how="any")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp Country        Date
# 3   port saint john's -31.6229   29.5448     21.00      ZA  1734587318
# 6   wailua homesteads  22.0669 -159.3780     23.44      US  1734587321
# 7        invercargill -46.4000  168.3500     18.90      NZ  1734587322
# 11           zalingei  12.9096   23.4741     22.46      SD  1734587327
# 13         los arabos  22.7281  -80.7214     21.50      CU  1734587329

# %% [markdown]
# ### New DataFrame called `hotel_df`.

# %%
# Create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df.copy()
hotel_df = hotel_df[["City", "Country", "Lat", "Lng"]]

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = [""] * len(hotel_df)

# Display sample data
hotel_df.head()
# Out:
#                  City Country      Lat       Lng Hotel Name
# 3   port saint john's      ZA -31.6229   29.5448
# 6   wailua homesteads      US  22.0669 -159.3780
# 7        invercargill      NZ -46.4000  168.3500
# 11           zalingei      SD  12.9096   23.4741
# 13         los arabos      CU  22.7281  -80.7214

# %% [markdown]
# ### Find the first hotel located within 10,000 metres of the city using Geoapify API

# %%
# Set parameters to search for a hotel

radius = 10000

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]

    # Parameters
    params = {
        "categories": "accommodation.hotel",
        "limit": 1,
        "filter": f"circle:{longitude},{latitude},{radius}",
        "bias": f"proximity:{longitude},{latitude}",
        "apiKey": geoapify_key
    }

    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"

    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionary
    name_address = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    name_address = name_address.json()

    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"

    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

hotel_df.to_csv("data/hotels.csv", header=True)

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port saint john's - nearest hotel: Outback Inn
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# humberto de campos - nearest hotel: No hotel found
# margaret river - nearest hotel: Margaret River Hotel
# forster - nearest hotel: No hotel found
# moyale - nearest hotel: Paul’s guest house
# lionel town - nearest hotel: No hotel found
# lincheng - nearest hotel: 小城之春假日酒店
# tuy hoa - nearest hotel: Nhu Y Hotel
# acapulco de juarez - nearest hotel: Hotel del Valle
# gweru - nearest hotel: Midlands Hotel
# codrington - nearest hotel: No hotel found
# qandala - nearest hotel: No hotel found
# basco - nearest hotel: Tawsen Hotel
# miracema do tocantins - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# oriximina - nearest hotel: No hotel found
# rio preto da eva - nearest hotel: Hotel Santo Antonio
# sechura - nearest hotel: Maximus Inn
# santa elena de uairen - nearest hotel: Posada Villa Fairmont
# kasane - nearest hotel: Kasane Travel Lodge
# paita - nearest hotel: Victor's
# zemio - nearest hotel: No hotel found
# port lincoln - nearest hotel: Boston Hotel
# ongwediva - nearest hotel: Afrika Stadt Haus
# sao vicente - nearest hotel: Pousada Vitória
# mokopane - nearest hotel: Oasis Hotel
# pandan - nearest hotel: No hotel found
# ghanzi - nearest hotel: Ghanzi farmhouse
# carnot - nearest hotel: No hotel found
# pedregal - nearest hotel: Aranjuez Hotel & Suites
# wuchuan - nearest hotel: No hotel found
# maryborough - nearest hotel: Post Office Hotel
# pleiku - nearest hotel: Green Bamboo - Tre Xanh Plaza Hotel
# hadibu - nearest hotel: No hotel found
# brisas de zicatela - nearest hotel: Casa de Olas
# camocim - nearest hotel: Hotel Camocim
# urangan - nearest hotel: Ramada
# sur - nearest hotel: Sur Hotel
# rehti - nearest hotel: No hotel found
# luena - nearest hotel: No hotel found
# katol - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# warah - nearest hotel: No hotel found
# puerto santander - nearest hotel: Hospedaje Dubai
# koulamoutou - nearest hotel: Motel de L'Amitié
# libenge - nearest hotel: Hôtel Wilo et Frères
# tura - nearest hotel: Hotel Polo Orchid
# howrah - nearest hotel: Sun India Guest House
# salalah - nearest hotel: Muscat International Hotel
# luganville - nearest hotel: Beachfront Resort
# curvelo - nearest hotel: Hotel Bandeirante
# aden - nearest hotel: فندق قصر الجزيرة
# inirida - nearest hotel: Residencias El Turista del Guainia
# posto fiscal rolim de moura - nearest hotel: No hotel found
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# graaff-reinet - nearest hotel: Profcon Resort
# bangassou - nearest hotel: Hotel De Tourisme
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# prado - nearest hotel: Pousada Recanto do Prado
# humaita - nearest hotel: Humaita Quality Hotel
# bandarbeyla - nearest hotel: No hotel found
# umm kaddadah - nearest hotel: No hotel found
# villa el carmen - nearest hotel: No hotel found
# okeho - nearest hotel: No hotel found
# barra de santo antonio - nearest hotel: Resort Fazenda Fiore
# kembe - nearest hotel: No hotel found
# cidreira - nearest hotel: Hotel Castelo
# bartica - nearest hotel: Rockville Hotel
# kindu - nearest hotel: Hôtel Karibu
# carutapera - nearest hotel: No hotel found
# santa luzia - nearest hotel: Alcoboca
# concordia - nearest hotel: D'Charruas
# bonito - nearest hotel: Hotel Pousada Arauna
# west end - nearest hotel: The Inn at Old Bahama Bay
# son la - nearest hotel: Khách sạn Mường Thanh Luxury Sơn La
# bubaque - nearest hotel: Chez Julio
# east london - nearest hotel: No hotel found
# selebi-phikwe - nearest hotel: Cresta Bosele Hotel
# baracoa - nearest hotel: Hotel Rio Miel
# jinghong - nearest hotel: No hotel found
# vila velha - nearest hotel: Hotel Prainha
# belabo - nearest hotel: No hotel found
# gondar - nearest hotel: Hotel Dashen
# conceicao da barra - nearest hotel: Porto Marlin Hotel
# tadine - nearest hotel: Hôtel Nengoné
# ouadda - nearest hotel: No hotel found
# luanda - nearest hotel: Hotel Forum
# effium - nearest hotel: No hotel found
# victorica - nearest hotel: Hotel Mazamet
# sucua - nearest hotel: Hostal Orellana
# sao joao nepomuceno - nearest hotel: Hotel Central
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# kabalo - nearest hotel: No hotel found
# ilhabela - nearest hotel: Vila Kebaya
# cestos city - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# kaithal - nearest hotel: Lovers vaishno
# kingaroy - nearest hotel: No hotel found
# anna regina - nearest hotel: Jaigobin Hotel
# guajara mirim - nearest hotel: Novo Hotel Campos
# dapa - nearest hotel: Island Suites
# port douglas - nearest hotel: Mantra Aqueous Port Douglas
#                   City Country      Lat       Lng  \
# 3    port saint john's      ZA -31.6229   29.5448
# 6    wailua homesteads      US  22.0669 -159.3780
# 7         invercargill      NZ -46.4000  168.3500
# 11            zalingei      SD  12.9096   23.4741
# 13          los arabos      CU  22.7281  -80.7214
# ..                 ...     ...      ...       ...
# 562           kingaroy      AU -26.5333  151.8333
# 564        anna regina      GY   7.2644  -58.5077
# 567      guajara mirim      BR -10.7828  -65.3394
# 570               dapa      PH   9.7594  126.0531
# 586       port douglas      AU -16.4833  145.4667
#
#                              Hotel Name
# 3                           Outback Inn
# 6    Hilton Garden Inn Kauai Wailua Bay
# 7                             The Grand
# 11                       No hotel found
# 13                       No hotel found
# ..                                  ...
# 562                      No hotel found
# 564                      Jaigobin Hotel
# 567                   Novo Hotel Campos
# 570                       Island Suites
# 586         Mantra Aqueous Port Douglas
#
# [172 rows x 5 columns]

# %% [markdown]
# ### Add hovers to the map

# %%
# Configure the map plot
hotel_plot = hotel_df.hvplot.points("Lng", "Lat", geo=True, tiles="OSM", size=25, color="City", 
                                    frame_width=700, frame_height=500, width=700, height=500, scale=1, 
                                    alpha=0.5, scaling_mode="stretch_both", hover_cols=["City", "Hotel Name", "Country"])

hv.save(hotel_plot, "visuals/hotel_map.html")

# Display the map
hotel_plot
# Out:
# WARNING:param.main: scaling_mode option not found for points plot with bokeh; similar options include: []
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p1994', ...)
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
